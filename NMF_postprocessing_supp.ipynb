# %%
# %matplotlib qt
import matplotlib.pyplot as plt
import hyperspy.api as hs
import pyxem as pxm
import numpy as np

from pathlib import Path
from matplotlib.colors import SymLogNorm
from skimage.measure import label

from matplotlib.colors import to_rgba
from matplotlib.colors import LinearSegmentedColormap

from skimage.filters.thresholding import try_all_threshold

from skimage.filters.thresholding import threshold_triangle, threshold_li, threshold_isodata

color_names = ['linen', 'darkorange', 'dodgerblue', 'forestgreen', 'red']
colors = [to_rgba(c) for c in color_names]

cmap = LinearSegmentedColormap.from_list('gt_cmap', colors, N=len(color_names))

gray_cmap = plt.colormaps.get('Greys')
gray_cmap.set_bad('lightblue')
# Out:
# WARNING:silx.opencl.common:Unable to import pyOpenCl. Please install it from: https://pypi.org/project/pyopencl

# %% [markdown]
# ## Convenient classes

# %%
class Decomposition(object):

    def __init__(self, datapath, label='', load_output_file=True, metadata_dict=None):
        self.datapath = Path(datapath)
        self.label = label
        self.loadings = hs.load(self.datapath.with_name(f'{self.datapath.stem}_loadings{self.datapath.suffix}'))
        self.factors = hs.load(self.datapath.with_name(f'{self.datapath.stem}_factors{self.datapath.suffix}'))

        if load_output_file:
            output_files = list(self.datapath.parent.glob(r'*.out'))
            if len(output_files) == 1:
                if metadata_dict is None:
                    metadata_dict = {}
                metadata_dict.update({'Decomposition_logfile': output_files[0].read_text()})
            else:
                if len(output_files) == 0:
                    print(f'No output log file detected')
                else:
                    print(f'{len(output_files)} output log files found, please add the correct output log file to the metadata of the loadings and factors manually instead')

        if metadata_dict is not None:
            if isinstance(metadata_dict, dict):
                self.loadings.metadata.add_dictionary({'Decomposition': metadata_dict})
                self.factors.metadata.add_dictionary({'Decomposition': metadata_dict})
            else:
                raise TypeError(f'Could not add {metadata_dict!r} as a metadata dictionary to {self!r}. Only dictionaries are allowed.')

    @property
    def output_dimension(self):
        return len(self.loadings)

    def __repr__(self):
        return f'{self.__class__.__name__}({self.datapath!r}, label={self.label!r})'

    def __str__(self):
        return f'{self.__class__.__name__} {self.label!s} with {self.output_dimension} components from path "{self.datapath.absolute()}"'

    def __iter__(self):
        for loading, factor in zip(self.loadings, self.factors):
            yield (loading, factor)

    def estimate_threshold(self, component, method=None):
        if method is None:
            _ = try_all_threshold(np.nan_to_num(self.loadings.inav[component].data, copy=True, nan=np.nanmin(self.loadings.inav[component].data)))
            fig = plt.gcf()
            fig.suptitle(component)
        else:
            return method(np.nan_to_num(self.loadings.inav[component].data, copy=True, nan=np.nanmin(self.loadings.inav[component].data)))

    def as_dictionary(self):
        return {'path': str(self.datapath.absolute()),
                'label': self.label,
                'loadings': self.loadings.deepcopy(),
                'factors': self.factors.deepcopy()
               }


    def plot(self, *args, **kwargs):
        hs.plot.plot_signals([self.loadings, self.factors], *args, **kwargs)

    def export_as_png(self, output_path=None, axis_size = 6, dpi=150, *args, **kwargs):
        for i, (loading, factor) in enumerate(self):
            
            if output_path is None:
                output_path = self.datapath
            else:
                output_path = Path(output_path)
            
            fig, axes = plt.subplots(nrows=1, ncols=2, subplot_kw={'xticks': [], 'yticks': []}, figsize=(axis_size*2, axis_size), dpi=dpi)
            axes[0].imshow(loading.data, *args, **kwargs)
            axes[1].imshow(factor.data, *args, **kwargs)
            axes[0].annotate(f'Loading {i}', (0.02, 0.98), xycoords='axes fraction', color='w', ha='left', va='top', bbox=dict(facecolor='k', alpha=0.5))
            axes[1].annotate(f'Factor {i}', (0.02, 0.98), xycoords='axes fraction', color='w', ha='left', va='top', bbox=dict(facecolor='k', alpha=0.5))
            plt.tight_layout()
            fig.savefig(output_path.with_name(f'{output_path.stem}_{i}.png'), dpi=dpi)
            
            fig = plt.figure(figsize=(axis_size, axis_size), dpi=dpi)
            ax = fig.add_axes([0, 0, 1, 1], xticks=[], yticks=[], frameon=False)
            ax.imshow(loading.data, *args, **kwargs)
            fig.savefig(output_path.with_name(f'{output_path.stem}_{i}_loading.png'), dpi=dpi)
            
            fig = plt.figure(figsize=(axis_size, axis_size), dpi=dpi)
            ax =  fig.add_axes([0, 0, 1, 1], xticks=[], yticks=[], frameon=False)
            ax.imshow(factor.data, *args, **kwargs)
            fig.savefig(output_path.with_name(f'{output_path.stem}_{i}_factor.png'), dpi=dpi)
            
            plt.close('all')

    def __hash__(self):
        return hash(tuple(self.loadings, self.factors))

class DecomposedPhase(object):

    def __init__(self, phase, decomposition, components, thresholds=None, value=1):
        self.phase = phase
        self.value = value
        self.decomposition = decomposition
        self.component_thresholds = dict()
        if thresholds is None:
            thresholds = [None]*len(components)
        [self.update_component(component, threshold) for (component, threshold) in zip(components, thresholds)]

    def __repr__(self):
        return f'{self.__class__.__name__}({self.phase!r}, {self.decomposition!r}, {list(self.component_thresholds.keys())!r}, {list(self.component_thresholds.values())!r}, value={self.value!r})'

    def __str__(self):
        return f'{self.__class__.__name__} for {self.phase!s} ({self.value}) based on {self.decomposition!s}.\nComponent thresholds:{self.component_thresholds!s}'

    @property
    def data(self):
        phase_map = np.zeros(self.decomposition.loadings.axes_manager.signal_shape, dtype=bool)
        if len(self.component_thresholds) > 0:
            for component in self.component_thresholds:
                phase_map += self.decomposition.loadings.inav[component].data>=self.component_thresholds[component]
        phase_map = phase_map * self.value
        return phase_map

    def as_signal(self):
        s = hs.signals.Signal2D(self.data)
        s.metadata.add_dictionary({
            'Phase': {
                'name': self.phase,
                'value': self.value,
                'decomposition': self.decomposition.as_dictionary(),
                'component_thresholds': {str(key): self.component_thresholds[key] for key in self.component_thresholds}},
            'General': {
                'title': f"{self.__class__.__name__} for {self.phase}"}
        })
        return s

    def update_component(self, component, threshold=None):
        if 0 <= component < len(self.decomposition.loadings):
            self.component_thresholds.update({component: threshold})
        else:
            raise IndexError(f'Cannot update component {component} in {self!r}, the component is out of range for decomposition {self.decomposition}')

    def remove_component(self, component):
        self.component_thresholds = {key: self.component_thresholds[key] for key in self.component_thresholds if key != component}

    def estimate_thresholds(self, method=None, update=False):
        thresholds = {component: self.decomposition.estimate_threshold(component, method) for component in self.component_thresholds}
        if update:
            [self.update_component(component, thresholds[component]) for component in thresholds]
        return thresholds

    def plot(self, axis_size = 6, dpi=150, savefig=False, *args, **kwargs):
        ncols = len(self.component_thresholds)+1
        fig, axes = plt.subplots(nrows=1, ncols=ncols, sharex=True, sharey=True, subplot_kw={'xticks': [], 'yticks': []}, figsize=(axis_size*ncols, axis_size), dpi=dpi)
        for i, component in enumerate(self.component_thresholds):
            axes[i].imshow(self.decomposition.loadings.inav[component].data,**kwargs)
            axes[i].annotate(f'Loading {component} of phase {self.phase}', (0.02, 0.98), xycoords='axes fraction', color='w', ha='left', va='top', bbox=dict(facecolor='k', alpha=0.5))
        axes[-1].imshow(self.data, cmap='Greys_r')
        plt.tight_layout()
        if savefig:
            fig.savefig(self.decomposition.datapath.with_name(f'{self.decomposition.datapath.stem}_{i}.png'), dpi=dpi)
            plt.close('all')

    def plot_component_histograms(self, components=None, axis_size = 6, dpi=150, savefig=False, *args, **kwargs):
        if components is None:
            components = list(self.component_thresholds.keys())
        ncols = len(components)
        print(ncols)
        fig, axes = plt.subplots(nrows=1, ncols=ncols, sharex=True, sharey=True)
        try:
            l = len(axes)
        except TypeError:
            l = 1
            axes = list([axes])
        for i, component in enumerate(components):
            component_threshold = self.component_thresholds.get(component, None)
            if component_threshold is None:
                raise ValueError(f'Cannot plot histogram of component {component} for {self!r}. No such component in the threshold dicrionary')
            axes[i].hist(self.decomposition.loadings.inav[component].data.flatten(), *args, **kwargs)
            axes[i].axvline(component_threshold, color='r')
            axes[i].set_title(f'Decomposition histogram of component {component}')
        plt.tight_layout()

    def make_mask(self, add_to=None):
        navigation_mask = hs.signals.Signal2D(self.data>=self.value, metadata={'General': {'title': f'{self.phase}'}})
        if add_to is not None:
            add_to.metadata.add_dictionary({'Preprocessing': {'Masks': {'Navigation': {self.phase: navigation_mask}}}})
        return navigation_mask

class PhaseMap(object):

    def __init__(self, phases):
        """
        Create a phase map from a list of PRIORITIZED phases. The first phase will have the highest priority, and the last will have the lowest.
        """
        type_test = [isinstance(phase, DecomposedPhase) for phase in phases]
        if not all(type_test):
            raise TypeError(f'Only DecompositionPhase objects are allowed to be specified in a PhaseMap: {type_test}')
        navigation_shapes = [phase.decomposition.loadings.axes_manager.signal_shape for phase in phases]
        if not all([navigation_shape == navigation_shapes[0] for navigation_shape in navigation_shapes]):
            raise ValueError(f'Navigation shapes in supplied phases does not match: {navigation_shapes}')

        self.phases = phases
        self.nx, self.ny = navigation_shapes[0]

    def __repr__(self):
        return f'{self.__class__.__name__}({self.phases!r})'

    def __str__(self):
        return f'{self.__class__.__name__} ({self.nx}x{self.ny}) of {self.phases!s}'

    def __iter__(self):
        for phase in self.phases:
            yield phase

    @property
    def data(self):
        phase_map = np.zeros((self.nx, self.ny), dtype=int)
        for phase in self.phases[::-1]:
            phase_map = np.where(phase.data>0, phase.data, phase_map)
        return phase_map


    def plot_phase_map(self, axis_size = 6, dpi=150, *args, **kwargs):
        fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw={'xticks': [], 'yticks': []}, figsize=(axis_size, axis_size), dpi=dpi, frameon=False)
        ax.imshow(self.data, *args, **kwargs)
        plt.tight_layout()

    def as_signal(self):
        s = hs.signals.Signal2D(self.data)
        s.metadata.add_dictionary({'Phases': {phase.phase: phase.as_signal() for phase in self}})
        s.metadata.General.title = r'Phase map'
        return s

    def save(self, filename, *args, **kwargs):
        self.as_signal().save(filename, *args, **kwargs)

    def make_RGBA(self, normalize_colors = True, normalize_alpha=True, figsize=(6, 6), dpi=150, figframe=True, axframe=False, insetframe=True):
        rgba_loadings = np.zeros(self.phases[0].decomposition.loadings.axes_manager.signal_shape + (4,))
        rgba_factors = np.zeros(self.phases[0].decomposition.factors.axes_manager.signal_shape + (4,))
        for i, phase in enumerate(self.phases):

            factor = np.zeros(phase.decomposition.factors.axes_manager.signal_shape)
            loading = np.zeros(phase.decomposition.loadings.axes_manager.signal_shape)
            for c in phase.component_thresholds:
                factor += phase.decomposition.factors.inav[c].data
                loading += np.nan_to_num(phase.decomposition.loadings.inav[c].data, copy=True, nan=0)

            if normalize_colors:
                factor = factor/np.nanmax(factor)
                loading = loading/np.nanmax(loading)

            rgba_loadings[:, :, i] = loading
            rgba_factors[:, :, i] = factor

            rgba_loadings[:, :, -1] += loading
            rgba_factors[:, :, -1] += factor

        if normalize_alpha:
            rgba_loadings[:, :, -1] /= np.nanmax(rgba_loadings[:, :, -1])
            rgba_factors[:, :, -1] /= np.nanmax(rgba_factors[:, :, -1])

        figure = plt.figure(figsize=figsize, dpi=dpi, frameon=figframe)
        ax = figure.add_axes([0, 0, 1, 1], xticks=[], yticks=[], frameon=axframe)
        ax.imshow(rgba_loadings)
        subax = figure.add_axes([0.75, 0.75, 0.25, 0.25], xticks=[], yticks=[], frameon=insetframe)
        subax.imshow(rgba_factors)
        return figure
        #figure.savefig(f'{datapath.stem}_decomposition_RGBA.png')

# %% [markdown]
# ### Assist functions

# %%
def load_decompositions(path):
    p = Path(path)
    decompositions = []
    for factor in p.glob(r'*_factors.hspy'):
        decompositions.append(Decomposition(factor.with_name(factor.name.replace('_factors', ''))))

    return sorted(decompositions, key=lambda decomp: decomp.output_dimension)

def read_logfile(path):
    p = Path(path)
    return p.read_text()

# %% [markdown]
# ## SVD

# %% [markdown]
# ### SVD of raw data

# %%
datapath = Path(r'Y:\Input\SPED\PhaseMappingPaperSupplementary\data\2022_06_20_prep\20220620_125312\svd\13332102\SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_SVD_None.hspy')
signal = hs.load(datapath, lazy=True)

# %%
signal.metadata
# Out:
# ├── Acquisition_instrument
# │   └── TEM
# │       ├── Acquisition_parameters
# │       │   ├── alpha = 5
# │       │   ├── beam_energy = 200.0
# │       │   ├── camera = Merlin
# │       │   ├── camera_length = 12.0
# │       │   ├── convergence_angle = None
# │       │   ├── exposure_time = None
# │       │   ├── microscope = 2100F
# │       │   ├── mode = NBD
# │       │   ├── notes = None
# │       │   ├── operator = Emil Christiansen
# │       │   ├── rocking_angle = 1.0
# │       │   ├── rocking_frequency = 100.0
# │       │   ├── scan_rotation = None
# │       │   ├── specimen = 2xxx 250C 24h
# │       │   └── spotsize = 1.0
# │       ├── Detector
# │       │   └── Diffraction
# │       │       └── camera_length = 22.586
# │       ├── beam_energy = 200.0
# │       ├── rocking_angle = 1.0
# │       └── rocking_frequency = 100.0
# ├── General
# │   ├── FileIO
# │   │   ├── 0
# │   │   │   ├── hyperspy_version = 1.7.0.dev0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-07-04T15:35:46.330928+02:00
# │   │   ├── 1
# │   │   │   ├── hyperspy_version = 1.7.0.dev0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-07-06T10:49:07.308573+02:00
# │   │   ├── 2
# │   │   │   ├── hyperspy_version = 1.7.0.dev0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-07-06T10:55:11.324672+02:00
# │   │   ├── 3
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-03T22:30:27.845177+01:00
# │   │   ├── 4
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-03T22:30:31.253745+01:00
# │   │   ├── 5
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-04T13:27:25.807617+01:00
# │   │   ├── 6
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-04T13:27:31.197359+01:00
# │   │   ├── 7
# │   │   │   ├── hyperspy_version = 1.7.0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-16T12:01:31.777625+01:00
# │   │   ├── 8
# │   │   │   ├── hyperspy_version = 1.7.0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-16T12:05:25.765643+01:00
# │   │   └── 9
# │   │       ├── hyperspy_version = 1.7.2
# │   │       ├── io_plugin = hyperspy.io_plugins.hspy
# │   │       ├── operation = load
# │   │       └── timestamp = 2022-11-16T14:49:47.496612+01:00
# │   └── title =
# ├── HDR
# │   ├── Acquisition Type (Normal, Th_scan, Config) = Normal
# │   ├── Active Counters = Counter 0
# │   ├── Assembly Size (NX1, 2X2) = 1x1
# │   ├── Chip ID = W559_G11, - , - , -
# │   ├── Chip Mode  (SPM, CSM, CM, CSCM) = SPM
# │   ├── Chip Type (Medipix 3.0, Medipix 3.1, Medipix 3RX) = Medipix 3RX
# │   ├── Counter Depth (number) = 12
# │   ├── DAC File = c:\MERLIN_Quad_Config\W559_G11\W559_G11_SPM.dacs,,,
# │   ├── DACs = 068,511,000,000,000,000,000,000,100,255,100,125,100,100,080,100,090,030,128,004,255,126,128,174,172,511,511; ; ;
# │   ├── Dead Time File = Dummy (C:\<NUL>\)
# │   ├── Flat Field File = None
# │   ├── Frames in Acquisition (Number) = 262144
# │   ├── Frames per Trigger (Number) = 1
# │   ├── Gain = SLGM
# │   ├── Gap Fill Mode = None
# │   ├── Humidity (%) = Board Humidity 0.000000
# │   ├── Medipix Clock (MHz) = 160MHz
# │   ├── Readout System = Merlin Quad
# │   ├── Sensor Bias (V) = 120 V
# │   ├── Sensor Polarity (Positive, Negative) = Positive
# │   ├── Software Version = 1.0.0.122
# │   ├── Temperature (C) = Board Temp 0.000000 Deg C
# │   ├── Thresholds (keV) = 4.000000E+1,5.110000E+2,0.000000E+0,0.000000E+0,0.000000E+0,0.000000E+0,0.000000E+0,0.000000E+0
# │   ├── Time and Date Stamp (day, mnth, yr, hr, min, s) = 20/06/2022 12:53:12
# │   ├── Trigger Start (Positive, Negative, Internal) = Rising Edge
# │   ├── Trigger Stop (Positive, Negative, Internal) = Internal
# │   └── bpc File = c:\MERLIN_Quad_Config\W559_G11\W559_G11_SPM.bpc,,,
# ├── Preprocessing
# │   ├── Centering
# │   │   ├── COM = <LazyDPCSignal2D, title: , dimensions: (2|512, 512)>
# │   │   ├── COM_mask
# │   │   │   ├── r = 12.5
# │   │   │   ├── x = 125
# │   │   │   └── y = 125
# │   │   ├── Shifts = <LazyBeamShift, title: , dimensions: (512, 512|2)>
# │   │   └── shift_estimate_mask = <LazySignal, title: , dimensions: (512, 512|)>
# │   ├── Masks
# │   │   ├── Diffraction
# │   │   │   ├── cutoff = <LazySignal2D, title: <0.7001057239470767 $A^{-1}$ mask, dimensions: (|128, 128)>
# │   │   │   ├── direct_beam = <LazySignal2D, title: >0.004612922335229383 $A^{-1}$ mask, dimensions: (|128, 128)>
# │   │   │   └── reflections = <LazySignal2D, title: Reflection mask, dimensions: (|128, 128)>
# │   │   └── Navigation
# │   │       ├── T1 = <LazySignal2D, title: T1, dimensions: (|512, 512)>
# │   │       └── theta_100 = <LazySignal2D, title: theta_100, dimensions: (|512, 512)>
# │   ├── Maximums = <LazyElectronDiffraction2D, title: , dimensions: (|128, 128)>
# │   └── VBF = <LazySignal2D, title: Integrated intensity, dimensions: (|512, 512)>
# └── Signal
#     └── signal_type = electron_diffraction

# %%
n = 30
signal.plot_explained_variance_ratio(n=n)
ax = plt.gca()
ax.set_title('')
plt.tight_layout()
fig = ax.get_figure()
fig.savefig(datapath.with_name(f'{datapath.stem}_scree.png'))
print(f'{int(signal.estimate_elbow_position(max_points=n))}')
# Out:
# 8

# %% [markdown]
# ### masked 1

# %%
datapath = Path(r'Y:\Input\SPED\PhaseMappingPaperSupplementary\data\2022_06_20_prep\20220620_125312\svd\navmasked1\13332104\SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_SVD_None_navmask-theta_100.hspy')
signal = hs.load(datapath, lazy=True)

# %%
n = 30
signal.plot_explained_variance_ratio(n=n)
ax = plt.gca()
ax.set_title('')
plt.tight_layout()
fig = ax.get_figure()
fig.savefig(datapath.with_name(f'{datapath.stem}_scree.png'))
print(f'{int(signal.estimate_elbow_position(max_points=n))}')
# Out:
# 4

# %% [markdown]
# ### Masked 2

# %%
datapath = Path(r'Y:\Input\SPED\PhaseMappingPaperSupplementary\data\2022_06_20_prep\20220620_125312\svd\navmasked2\13332105\SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_SVD_None_navmask-T1_navmask-theta_100.hspy')
signal = hs.load(datapath, lazy=True)

# %%
n = 30
signal.plot_explained_variance_ratio(n=n)
ax = plt.gca()
ax.set_title('')
plt.tight_layout()
fig = ax.get_figure()
fig.savefig(datapath.with_name(f'{datapath.stem}_scree.png'))
print(f'{int(signal.estimate_elbow_position(max_points=n))}')
# Out:
# 2

# %% [markdown]
# ## NMF

# %% [markdown]
# ### 1st iteration

# %%
decomposition_1 = Decomposition(r'Y:\Input\SPED\PhaseMappingPaperSupplementary\data\2022_06_20_prep\20220620_125312\nndsvd\13033674\SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_5.hspy')
decomposition_1.plot()

# %%
decomposition_1.export_as_png(cmap=gray_cmap)

# %% [markdown]
# Estimate thresholds

# %%
[decomposition_1.estimate_threshold(component) for component in range(decomposition_1.output_dimension)]
# Out:
# skimage.filters.thresholding.threshold_isodata
# skimage.filters.thresholding.threshold_li
# skimage.filters.thresholding.threshold_mean
# skimage.filters.thresholding.threshold_minimum
# skimage.filters.thresholding.threshold_otsu
# skimage.filters.thresholding.threshold_triangle
# skimage.filters.thresholding.threshold_yen
# skimage.filters.thresholding.threshold_isodata
# skimage.filters.thresholding.threshold_li
# skimage.filters.thresholding.threshold_mean
# skimage.filters.thresholding.threshold_minimum
# skimage.filters.thresholding.threshold_otsu
# skimage.filters.thresholding.threshold_triangle
# skimage.filters.thresholding.threshold_yen
# skimage.filters.thresholding.threshold_isodata
# skimage.filters.thresholding.threshold_li
# skimage.filters.thresholding.threshold_mean
# skimage.filters.thresholding.threshold_minimum
# skimage.filters.thresholding.threshold_otsu
# skimage.filters.thresholding.threshold_triangle
# skimage.filters.thresholding.threshold_yen
# [None, None, None]

# %% [markdown]
# Make phasemaps

# %%
thetap_100 = DecomposedPhase('theta_100', decomposition_1, [1, 2], value=1)

thethap_100_thresholds = thetap_100.estimate_thresholds(method=threshold_triangle, update=True)

print(thetap_100.component_thresholds)

p = PhaseMap([thetap_100])
p.plot_phase_map(cmap=cmap, vmin=0, vmax=4)
# Out:
# {1: 0.014498123, 2: 0.015992213}

# %% [markdown]
# Make exclusion mask

# %%
signalpath = Path(r'Y:\Input\SPED\PhaseMappingPaperSupplementary\data\2022_06_20_prep\20220620_125312\Normalized\SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed.hspy')
signal = hs.load(signalpath, lazy=True, mode='a')
print(signal.metadata)
signal.metadata.Preprocessing.Masks.Navigation.T1.plot()
thetap_100.make_mask(add_to=signal)

print(signal.metadata)
signal.save(signalpath, write_dataset=False, close_file=True)
#signal.close_file()
# Out:
# ├── Acquisition_instrument
# │   └── TEM
# │       ├── Acquisition_parameters
# │       │   ├── alpha = 5
# │       │   ├── beam_energy = 200.0
# │       │   ├── camera = Merlin
# │       │   ├── camera_length = 12.0
# │       │   ├── convergence_angle = None
# │       │   ├── exposure_time = None
# │       │   ├── microscope = 2100F
# │       │   ├── mode = NBD
# │       │   ├── notes = None
# │       │   ├── operator = Emil Christiansen
# │       │   ├── rocking_angle = 1.0
# │       │   ├── rocking_frequency = 100.0
# │       │   ├── scan_rotation = None
# │       │   ├── specimen = 2xxx 250C 24h
# │       │   └── spotsize = 1.0
# │       ├── Detector
# │       │   └── Diffraction
# │       │       └── camera_length = 22.586
# │       ├── beam_energy = 200.0
# │       ├── rocking_angle = 1.0
# │       └── rocking_frequency = 100.0
# ├── General
# │   ├── FileIO
# │   │   ├── 0
# │   │   │   ├── hyperspy_version = 1.7.0.dev0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-07-04T15:35:46.330928+02:00
# │   │   ├── 1
# │   │   │   ├── hyperspy_version = 1.7.0.dev0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-07-06T10:49:07.308573+02:00
# │   │   ├── 2
# │   │   │   ├── hyperspy_version = 1.7.0.dev0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-07-06T10:55:11.324672+02:00
# │   │   ├── 3
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-03T22:30:27.845177+01:00
# │   │   ├── 4
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-03T22:30:31.253745+01:00
# │   │   ├── 5
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-04T13:27:25.807617+01:00
# │   │   ├── 6
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-04T13:27:31.197359+01:00
# │   │   ├── 7
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-17T10:48:58.454979+01:00
# │   │   ├── 8
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-17T10:49:05.589204+01:00
# │   │   └── 9
# │   │       ├── hyperspy_version = 1.7.2
# │   │       ├── io_plugin = hyperspy.io_plugins.hspy
# │   │       ├── operation = load
# │   │       └── timestamp = 2022-11-17T11:59:06.688449+01:00
# │   └── title =
# ├── HDR
# │   ├── Acquisition Type (Normal, Th_scan, Config) = Normal
# │   ├── Active Counters = Counter 0
# │   ├── Assembly Size (NX1, 2X2) = 1x1
# │   ├── Chip ID = W559_G11, - , - , -
# │   ├── Chip Mode  (SPM, CSM, CM, CSCM) = SPM
# │   ├── Chip Type (Medipix 3.0, Medipix 3.1, Medipix 3RX) = Medipix 3RX
# │   ├── Counter Depth (number) = 12
# │   ├── DAC File = c:\MERLIN_Quad_Config\W559_G11\W559_G11_SPM.dacs,,,
# │   ├── DACs = 068,511,000,000,000,000,000,000,100,255,100,125,100,100,080,100,090,030,128,004,255,126,128,174,172,511,511; ; ;
# │   ├── Dead Time File = Dummy (C:\<NUL>\)
# │   ├── Flat Field File = None
# │   ├── Frames in Acquisition (Number) = 262144
# │   ├── Frames per Trigger (Number) = 1
# │   ├── Gain = SLGM
# │   ├── Gap Fill Mode = None
# │   ├── Humidity (%) = Board Humidity 0.000000
# │   ├── Medipix Clock (MHz) = 160MHz
# │   ├── Readout System = Merlin Quad
# │   ├── Sensor Bias (V) = 120 V
# │   ├── Sensor Polarity (Positive, Negative) = Positive
# │   ├── Software Version = 1.0.0.122
# │   ├── Temperature (C) = Board Temp 0.000000 Deg C
# │   ├── Thresholds (keV) = 4.000000E+1,5.110000E+2,0.000000E+0,0.000000E+0,0.000000E+0,0.000000E+0,0.000000E+0,0.000000E+0
# │   ├── Time and Date Stamp (day, mnth, yr, hr, min, s) = 20/06/2022 12:53:12
# │   ├── Trigger Start (Positive, Negative, Internal) = Rising Edge
# │   ├── Trigger Stop (Positive, Negative, Internal) = Internal
# │   └── bpc File = c:\MERLIN_Quad_Config\W559_G11\W559_G11_SPM.bpc,,,
# ├── Preprocessing
# │   ├── Centering
# │   │   ├── COM = <LazyDPCSignal2D, title: , dimensions: (2|512, 512)>
# │   │   ├── COM_mask
# │   │   │   ├── r = 12.5
# │   │   │   ├── x = 125
# │   │   │   └── y = 125
# │   │   ├── Shifts = <LazyBeamShift, title: , dimensions: (512, 512|2)>
# │   │   └── shift_estimate_mask = <LazySignal, title: , dimensions: (512, 512|)>
# │   ├── Masks
# │   │   ├── Diffraction
# │   │   │   ├── cutoff = <LazySignal2D, title: <0.7001057239470767 $A^{-1}$ mask, dimensions: (|128, 128)>
# │   │   │   ├── direct_beam = <LazySignal2D, title: >0.004612922335229383 $A^{-1}$ mask, dimensions: (|128, 128)>
# │   │   │   └── reflections = <LazySignal2D, title: Reflection mask, dimensions: (|128, 128)>
# │   │   └── Navigation
# │   │       ├── T1 = <LazySignal2D, title: T1, dimensions: (|512, 512)>
# │   │       └── theta_100 = <LazySignal2D, title: theta_100, dimensions: (|512, 512)>
# │   ├── Maximums = <LazyElectronDiffraction2D, title: , dimensions: (|128, 128)>
# │   └── VBF = <LazySignal2D, title: Integrated intensity, dimensions: (|512, 512)>
# └── Signal
#     └── signal_type = electron_diffraction
#
# ├── Acquisition_instrument
# │   └── TEM
# │       ├── Acquisition_parameters
# │       │   ├── alpha = 5
# │       │   ├── beam_energy = 200.0
# │       │   ├── camera = Merlin
# │       │   ├── camera_length = 12.0
# │       │   ├── convergence_angle = None
# │       │   ├── exposure_time = None
# │       │   ├── microscope = 2100F
# │       │   ├── mode = NBD
# │       │   ├── notes = None
# │       │   ├── operator = Emil Christiansen
# │       │   ├── rocking_angle = 1.0
# │       │   ├── rocking_frequency = 100.0
# │       │   ├── scan_rotation = None
# │       │   ├── specimen = 2xxx 250C 24h
# │       │   └── spotsize = 1.0
# │       ├── Detector
# │       │   └── Diffraction
# │       │       └── camera_length = 22.586
# │       ├── beam_energy = 200.0
# │       ├── rocking_angle = 1.0
# │       └── rocking_frequency = 100.0
# ├── General
# │   ├── FileIO
# │   │   ├── 0
# │   │   │   ├── hyperspy_version = 1.7.0.dev0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-07-04T15:35:46.330928+02:00
# │   │   ├── 1
# │   │   │   ├── hyperspy_version = 1.7.0.dev0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-07-06T10:49:07.308573+02:00
# │   │   ├── 2
# │   │   │   ├── hyperspy_version = 1.7.0.dev0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-07-06T10:55:11.324672+02:00
# │   │   ├── 3
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-03T22:30:27.845177+01:00
# │   │   ├── 4
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-03T22:30:31.253745+01:00
# │   │   ├── 5
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-04T13:27:25.807617+01:00
# │   │   ├── 6
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-04T13:27:31.197359+01:00
# │   │   ├── 7
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-17T10:48:58.454979+01:00
# │   │   ├── 8
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-17T10:49:05.589204+01:00
# │   │   └── 9
# │   │       ├── hyperspy_version = 1.7.2
# │   │       ├── io_plugin = hyperspy.io_plugins.hspy
# │   │       ├── operation = load
# │   │       └── timestamp = 2022-11-17T11:59:06.688449+01:00
# │   └── title =
# ├── HDR
# │   ├── Acquisition Type (Normal, Th_scan, Config) = Normal
# │   ├── Active Counters = Counter 0
# │   ├── Assembly Size (NX1, 2X2) = 1x1
# │   ├── Chip ID = W559_G11, - , - , -
# │   ├── Chip Mode  (SPM, CSM, CM, CSCM) = SPM
# │   ├── Chip Type (Medipix 3.0, Medipix 3.1, Medipix 3RX) = Medipix 3RX
# │   ├── Counter Depth (number) = 12
# │   ├── DAC File = c:\MERLIN_Quad_Config\W559_G11\W559_G11_SPM.dacs,,,
# │   ├── DACs = 068,511,000,000,000,000,000,000,100,255,100,125,100,100,080,100,090,030,128,004,255,126,128,174,172,511,511; ; ;
# │   ├── Dead Time File = Dummy (C:\<NUL>\)
# │   ├── Flat Field File = None
# │   ├── Frames in Acquisition (Number) = 262144
# │   ├── Frames per Trigger (Number) = 1
# │   ├── Gain = SLGM
# │   ├── Gap Fill Mode = None
# │   ├── Humidity (%) = Board Humidity 0.000000
# │   ├── Medipix Clock (MHz) = 160MHz
# │   ├── Readout System = Merlin Quad
# │   ├── Sensor Bias (V) = 120 V
# │   ├── Sensor Polarity (Positive, Negative) = Positive
# │   ├── Software Version = 1.0.0.122
# │   ├── Temperature (C) = Board Temp 0.000000 Deg C
# │   ├── Thresholds (keV) = 4.000000E+1,5.110000E+2,0.000000E+0,0.000000E+0,0.000000E+0,0.000000E+0,0.000000E+0,0.000000E+0
# │   ├── Time and Date Stamp (day, mnth, yr, hr, min, s) = 20/06/2022 12:53:12
# │   ├── Trigger Start (Positive, Negative, Internal) = Rising Edge
# │   ├── Trigger Stop (Positive, Negative, Internal) = Internal
# │   └── bpc File = c:\MERLIN_Quad_Config\W559_G11\W559_G11_SPM.bpc,,,
# ├── Preprocessing
# │   ├── Centering
# │   │   ├── COM = <LazyDPCSignal2D, title: , dimensions: (2|512, 512)>
# │   │   ├── COM_mask
# │   │   │   ├── r = 12.5
# │   │   │   ├── x = 125
# │   │   │   └── y = 125
# │   │   ├── Shifts = <LazyBeamShift, title: , dimensions: (512, 512|2)>
# │   │   └── shift_estimate_mask = <LazySignal, title: , dimensions: (512, 512|)>
# │   ├── Masks
# │   │   ├── Diffraction
# │   │   │   ├── cutoff = <LazySignal2D, title: <0.7001057239470767 $A^{-1}$ mask, dimensions: (|128, 128)>
# │   │   │   ├── direct_beam = <LazySignal2D, title: >0.004612922335229383 $A^{-1}$ mask, dimensions: (|128, 128)>
# │   │   │   └── reflections = <LazySignal2D, title: Reflection mask, dimensions: (|128, 128)>
# │   │   └── Navigation
# │   │       ├── T1 = <LazySignal2D, title: T1, dimensions: (|512, 512)>
# │   │       └── theta_100 = <Signal2D, title: theta_100, dimensions: (|512, 512)>
# │   ├── Maximums = <LazyElectronDiffraction2D, title: , dimensions: (|128, 128)>
# │   └── VBF = <LazySignal2D, title: Integrated intensity, dimensions: (|512, 512)>
# └── Signal
#     └── signal_type = electron_diffraction
# Overwrite '\\idun-samba1.hpc.ntnu.no\emilc\Input\SPED\PhaseMappingPaperSupplementary\data\2022_06_20_prep\20220620_125312\Normalized\SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed.hspy' (y/n)?
# y

# %% [markdown]
# ### 2nd iteration

# %%
decomposition_2 = Decomposition(r'Y:\Input\SPED\PhaseMappingPaperSupplementary\data\2022_06_20_prep\20220620_125312\nndsvd\navmasked1\13037984\SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_5_navmask-theta_100.hspy')
print(decomposition_2.factors.metadata.Decomposition.Decomposition_logfile)
decomposition_2.plot()
T1 = DecomposedPhase('T1', decomposition_2, [1, 2], value=3)
T1.estimate_thresholds()
# Out:
# we are running from this directory: /cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1
# The name of the job is: nndsvd2
# The job ID is 13037984
# The job was run on these nodes: idun-06-14
# Number of nodes: 1
# We are using 20 cores
# We are using 20 cores per node
# Total of  cores
# ERROR:numba.cuda.cudadrv.driver:Call to cuInit results in CUDA_ERROR_NO_DEVICE
# WARNING:silx.opencl.common:Unable to import pyOpenCl. Please install it from: https://pypi.org/project/pyopencl
# 03-11-2022 22:38:49 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition script with arguments:
# 	'hs_file' = /cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/Normalized/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed.hspy
# 	'scale' = None
# 	'logscale' = False
# 	'log_offset' = None
# 	'mask' = True
# 	'navmask' = ['theta_100']
# 	'apply_mask' = False
# 	'cutoff' = None
# 	'algorithm' = NMF
# 	'components' = [2, 3, 4, 5, 6, 7, 8, 9, 10]
# 	'poissonian' = True
# 	'max_iter' = 10000
# 	'initialization' = nndsvd
# 	'random_state' = None
# 	'copy' = False
# 	'output_path' = 13037984
# 	'store_signal' = False
# 	'lazy' = False
# 	'precision' = float32
# 	'verbosity' = 2
# 03-11-2022 22:38:49 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Specified output path "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1/13037984" does not exists. I will attempt to create it
# 03-11-2022 22:38:49 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Creating output directory "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1/13037984"
# 03-11-2022 22:38:49 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Created output directory successfully.
# 03-11-2022 22:38:49 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will put outputs at "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1/13037984"
# 03-11-2022 22:38:49 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Loading data signal "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/Normalized/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed.hspy
# 03-11-2022 22:41:00 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Getting diffraction mask signals
# 03-11-2022 22:41:00 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Found 3 diffraction masks in the metadata
# 03-11-2022 22:41:00 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Adding mask <Signal2D, title: <0.7001057239470767 $A^{-1}$ mask, dimensions: (|128, 128)> to diffraction mask
# 03-11-2022 22:41:00 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Adding mask <Signal2D, title: >0.004612922335229383 $A^{-1}$ mask, dimensions: (|128, 128)> to diffraction mask
# 03-11-2022 22:41:00 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Adding mask <Signal2D, title: Reflection mask, dimensions: (|128, 128)> to diffraction mask
# 03-11-2022 22:41:00 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Getting navigation mask signals
# 03-11-2022 22:41:00 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Found 1 navigation masks in the metadata
# 03-11-2022 22:41:00 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Filtering masks based on selection: ['theta_100'].
# 03-11-2022 22:41:00 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Adding mask <Signal2D, title: theta_100, dimensions: (|512, 512)> to navigation mask
# 03-11-2022 22:41:00 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Transposing navigation mask
# 03-11-2022 22:41:00 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 0 of 9
# 03-11-2022 22:41:00 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 03-11-2022 22:41:00 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 03-11-2022 22:41:00 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 2 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# 03-11-2022 22:48:34 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 453.7582607269287 seconds
# 03-11-2022 22:48:34 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=2)
# 03-11-2022 22:48:34 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 11.611680142109334
# 03-11-2022 22:48:34 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 1229
# 03-11-2022 22:48:34 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1/13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_2_navmask-theta_100.hspy"
# 03-11-2022 22:48:34 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_2_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 03-11-2022 22:48:34 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 03-11-2022 22:48:34 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 03-11-2022 22:48:34 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 0 of 9
#
# 03-11-2022 22:48:34 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 1 of 9
# 03-11-2022 22:48:34 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 03-11-2022 22:48:34 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 03-11-2022 22:48:34 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 3 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# 03-11-2022 22:58:55 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 620.9822249412537 seconds
# 03-11-2022 22:58:55 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=3)
# 03-11-2022 22:58:55 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 11.044105538742325
# 03-11-2022 22:58:55 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 1909
# 03-11-2022 22:58:55 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1/13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_3_navmask-theta_100.hspy"
# 03-11-2022 22:58:55 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_3_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 03-11-2022 22:58:55 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 03-11-2022 22:58:55 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 03-11-2022 22:58:55 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 1 of 9
#
# 03-11-2022 22:58:55 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 2 of 9
# 03-11-2022 22:58:55 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 03-11-2022 22:58:55 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 03-11-2022 22:58:55 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 4 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# 03-11-2022 23:15:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 968.7463173866272 seconds
# 03-11-2022 23:15:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=4)
# 03-11-2022 23:15:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 10.785293130582852
# 03-11-2022 23:15:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 2090
# 03-11-2022 23:15:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1/13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_4_navmask-theta_100.hspy"
# 03-11-2022 23:15:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_4_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 03-11-2022 23:15:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 03-11-2022 23:15:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 03-11-2022 23:15:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 2 of 9
#
# 03-11-2022 23:15:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 3 of 9
# 03-11-2022 23:15:04 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 03-11-2022 23:15:04 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 03-11-2022 23:15:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 5 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# 03-11-2022 23:45:06 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 1802.199235200882 seconds
# 03-11-2022 23:45:06 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=5)
# 03-11-2022 23:45:06 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 10.699611649640607
# 03-11-2022 23:45:06 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 4305
# 03-11-2022 23:45:06 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1/13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_5_navmask-theta_100.hspy"
# 03-11-2022 23:45:06 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_5_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 03-11-2022 23:45:06 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 03-11-2022 23:45:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 03-11-2022 23:45:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 3 of 9
#
# 03-11-2022 23:45:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 4 of 9
# 03-11-2022 23:45:07 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 03-11-2022 23:45:07 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 03-11-2022 23:45:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 6 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# 04-11-2022 00:14:44 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 1777.5920405387878 seconds
# 04-11-2022 00:14:44 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=6)
# 04-11-2022 00:14:44 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 10.617163427240001
# 04-11-2022 00:14:44 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 4132
# 04-11-2022 00:14:44 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1/13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_6_navmask-theta_100.hspy"
# 04-11-2022 00:14:44 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_6_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 04-11-2022 00:14:44 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 04-11-2022 00:14:44 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 04-11-2022 00:14:45 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 4 of 9
#
# 04-11-2022 00:14:45 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 5 of 9
# 04-11-2022 00:14:45 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 04-11-2022 00:14:45 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 04-11-2022 00:14:45 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 7 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# 04-11-2022 01:03:54 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 2949.616151332855 seconds
# 04-11-2022 01:03:54 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=7)
# 04-11-2022 01:03:54 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 10.56711599395443
# 04-11-2022 01:03:54 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 7109
# 04-11-2022 01:03:54 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1/13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_7_navmask-theta_100.hspy"
# 04-11-2022 01:03:54 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_7_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 04-11-2022 01:03:54 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 04-11-2022 01:03:54 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 04-11-2022 01:03:55 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 5 of 9
#
# 04-11-2022 01:03:55 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 6 of 9
# 04-11-2022 01:03:55 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 04-11-2022 01:03:55 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 04-11-2022 01:03:55 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 8 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# 04-11-2022 01:46:46 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 2571.196680545807 seconds
# 04-11-2022 01:46:46 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=8)
# 04-11-2022 01:46:46 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 10.522614603358821
# 04-11-2022 01:46:46 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 6322
# 04-11-2022 01:46:46 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1/13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_8_navmask-theta_100.hspy"
# 04-11-2022 01:46:46 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_8_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 04-11-2022 01:46:46 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 04-11-2022 01:46:46 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 04-11-2022 01:46:46 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 6 of 9
#
# 04-11-2022 01:46:46 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 7 of 9
# 04-11-2022 01:46:46 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 04-11-2022 01:46:46 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 04-11-2022 01:46:46 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 9 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# 04-11-2022 02:32:49 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 2762.737975358963 seconds
# 04-11-2022 02:32:49 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=9)
# 04-11-2022 02:32:49 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 10.48086257063842
# 04-11-2022 02:32:49 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 6260
# 04-11-2022 02:32:49 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1/13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_9_navmask-theta_100.hspy"
# 04-11-2022 02:32:49 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_9_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 04-11-2022 02:32:49 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 04-11-2022 02:32:49 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 04-11-2022 02:32:50 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 7 of 9
#
# 04-11-2022 02:32:50 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 8 of 9
# 04-11-2022 02:32:50 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 04-11-2022 02:32:50 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 04-11-2022 02:32:50 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 10 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# 04-11-2022 03:41:16 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 4105.95788860321 seconds
# 04-11-2022 03:41:16 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=10)
# 04-11-2022 03:41:16 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 10.44782554964526
# 04-11-2022 03:41:16 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 6324
# 04-11-2022 03:41:16 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1/13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_10_navmask-theta_100.hspy"
# 04-11-2022 03:41:16 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13037984/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_10_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 04-11-2022 03:41:16 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 04-11-2022 03:41:16 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 04-11-2022 03:41:16 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 8 of 9
#
# 04-11-2022 03:41:16 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition script
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=2
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=2)
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=3
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=3)
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=4
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=4)
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=5
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=5)
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=6
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=6)
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=7
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=7)
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=8
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=8)
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=9
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=9)
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=10
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=10)
# JobId=13037984 JobName=nndsvd2
#    UserId=emilc(1088898) GroupId=kfys_a(14843) MCS_label=N/A
#    Priority=1053942 Nice=0 Account=share-nv-fys-tem QOS=high
#    JobState=RUNNING Reason=None Dependency=(null)
#    Requeue=1 Restarts=0 BatchFlag=1 Reboot=0 ExitCode=0:0
#    DerivedExitCode=0:0
#    RunTime=05:02:41 TimeLimit=10:00:00 TimeMin=N/A
#    SubmitTime=2022-11-03T22:38:23 EligibleTime=2022-11-03T22:38:23
#    AccrueTime=2022-11-03T22:38:23
#    StartTime=2022-11-03T22:38:37 EndTime=2022-11-04T08:38:37 Deadline=N/A
#    SuspendTime=None SecsPreSuspend=0 LastSchedEval=2022-11-03T22:38:37 Scheduler=Backfill
#    Partition=CPUQ AllocNode:Sid=idun-login1:2428492
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=idun-06-14
#    BatchHost=idun-06-14
#    NumNodes=1 NumCPUs=20 NumTasks=1 CPUs/Task=20 ReqB:S:C:T=0:0:*:*
#    TRES=cpu=20,mem=62.50G,node=1,billing=20
#    Socks/Node=* NtasksPerN:B:S:C=0:0:*:* CoreSpec=*
#    JOB_GRES=(null)
#      Nodes=idun-06-14 CPU_IDs=0-19 Mem=64000 GRES=
#    MinCPUsNode=20 MinMemoryNode=62.50G MinTmpDiskNode=0
#    Features=(null) DelayBoot=00:00:00
#    OverSubscribe=OK Contiguous=0 Licenses=(null) Network=(null)
#    Command=/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1/decompose.slurm
#    WorkDir=/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1
#    StdErr=/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1/NMF_nndsvd-13037984.out
#    StdIn=/dev/null
#    StdOut=/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked1/NMF_nndsvd-13037984.out
#    Power=
#    MailUser=emil.christiansen@ntnu.no MailType=INVALID_DEPEND,BEGIN,END,FAIL,REQUEUE,STAGE_OUT
# skimage.filters.thresholding.threshold_isodata
# skimage.filters.thresholding.threshold_li
# skimage.filters.thresholding.threshold_mean
# skimage.filters.thresholding.threshold_minimum
# skimage.filters.thresholding.threshold_otsu
# skimage.filters.thresholding.threshold_triangle
# skimage.filters.thresholding.threshold_yen
# skimage.filters.thresholding.threshold_isodata
# skimage.filters.thresholding.threshold_li
# skimage.filters.thresholding.threshold_mean
# skimage.filters.thresholding.threshold_minimum
# skimage.filters.thresholding.threshold_otsu
# skimage.filters.thresholding.threshold_triangle
# skimage.filters.thresholding.threshold_yen
# {1: None, 2: None}

# %%
decomposition_2.export_as_png(cmap=gray_cmap)

# %%
T1.estimate_thresholds(method=threshold_triangle, update=True)
print(T1.component_thresholds)
T1.plot()
# Out:
# {1: 0.011392273008823395, 2: 0.009682850941317156}

# %%
T1.plot()

# %%
p = PhaseMap([thetap_100, T1])
p.plot_phase_map(cmap=cmap, vmin=0, vmax=4)

# %%
signalpath = Path(r'Y:\Input\SPED\PhaseMappingPaperSupplementary\data\2022_06_20_prep\20220620_125312\Normalized\SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed.hspy')
signal = hs.load(signalpath, lazy=True, mode='a')
print(signal.metadata)
signal.metadata.Preprocessing.Masks.Navigation.T1.plot()
T1.make_mask(add_to=signal)

print(signal.metadata)
signal.save(signalpath, write_dataset=False, close_file=True)
#signal.close_file()
# Out:
# ├── Acquisition_instrument
# │   └── TEM
# │       ├── Acquisition_parameters
# │       │   ├── alpha = 5
# │       │   ├── beam_energy = 200.0
# │       │   ├── camera = Merlin
# │       │   ├── camera_length = 12.0
# │       │   ├── convergence_angle = None
# │       │   ├── exposure_time = None
# │       │   ├── microscope = 2100F
# │       │   ├── mode = NBD
# │       │   ├── notes = None
# │       │   ├── operator = Emil Christiansen
# │       │   ├── rocking_angle = 1.0
# │       │   ├── rocking_frequency = 100.0
# │       │   ├── scan_rotation = None
# │       │   ├── specimen = 2xxx 250C 24h
# │       │   └── spotsize = 1.0
# │       ├── Detector
# │       │   └── Diffraction
# │       │       └── camera_length = 22.586
# │       ├── beam_energy = 200.0
# │       ├── rocking_angle = 1.0
# │       └── rocking_frequency = 100.0
# ├── General
# │   ├── FileIO
# │   │   ├── 0
# │   │   │   ├── hyperspy_version = 1.7.0.dev0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-07-04T15:35:46.330928+02:00
# │   │   ├── 1
# │   │   │   ├── hyperspy_version = 1.7.0.dev0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-07-06T10:49:07.308573+02:00
# │   │   ├── 10
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-17T11:59:11.705391+01:00
# │   │   ├── 11
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-17T11:59:58.390211+01:00
# │   │   ├── 2
# │   │   │   ├── hyperspy_version = 1.7.0.dev0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-07-06T10:55:11.324672+02:00
# │   │   ├── 3
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-03T22:30:27.845177+01:00
# │   │   ├── 4
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-03T22:30:31.253745+01:00
# │   │   ├── 5
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-04T13:27:25.807617+01:00
# │   │   ├── 6
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-04T13:27:31.197359+01:00
# │   │   ├── 7
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-17T10:48:58.454979+01:00
# │   │   ├── 8
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-17T10:49:05.589204+01:00
# │   │   └── 9
# │   │       ├── hyperspy_version = 1.7.2
# │   │       ├── io_plugin = hyperspy.io_plugins.hspy
# │   │       ├── operation = load
# │   │       └── timestamp = 2022-11-17T11:59:06.688449+01:00
# │   └── title =
# ├── HDR
# │   ├── Acquisition Type (Normal, Th_scan, Config) = Normal
# │   ├── Active Counters = Counter 0
# │   ├── Assembly Size (NX1, 2X2) = 1x1
# │   ├── Chip ID = W559_G11, - , - , -
# │   ├── Chip Mode  (SPM, CSM, CM, CSCM) = SPM
# │   ├── Chip Type (Medipix 3.0, Medipix 3.1, Medipix 3RX) = Medipix 3RX
# │   ├── Counter Depth (number) = 12
# │   ├── DAC File = c:\MERLIN_Quad_Config\W559_G11\W559_G11_SPM.dacs,,,
# │   ├── DACs = 068,511,000,000,000,000,000,000,100,255,100,125,100,100,080,100,090,030,128,004,255,126,128,174,172,511,511; ; ;
# │   ├── Dead Time File = Dummy (C:\<NUL>\)
# │   ├── Flat Field File = None
# │   ├── Frames in Acquisition (Number) = 262144
# │   ├── Frames per Trigger (Number) = 1
# │   ├── Gain = SLGM
# │   ├── Gap Fill Mode = None
# │   ├── Humidity (%) = Board Humidity 0.000000
# │   ├── Medipix Clock (MHz) = 160MHz
# │   ├── Readout System = Merlin Quad
# │   ├── Sensor Bias (V) = 120 V
# │   ├── Sensor Polarity (Positive, Negative) = Positive
# │   ├── Software Version = 1.0.0.122
# │   ├── Temperature (C) = Board Temp 0.000000 Deg C
# │   ├── Thresholds (keV) = 4.000000E+1,5.110000E+2,0.000000E+0,0.000000E+0,0.000000E+0,0.000000E+0,0.000000E+0,0.000000E+0
# │   ├── Time and Date Stamp (day, mnth, yr, hr, min, s) = 20/06/2022 12:53:12
# │   ├── Trigger Start (Positive, Negative, Internal) = Rising Edge
# │   ├── Trigger Stop (Positive, Negative, Internal) = Internal
# │   └── bpc File = c:\MERLIN_Quad_Config\W559_G11\W559_G11_SPM.bpc,,,
# ├── Preprocessing
# │   ├── Centering
# │   │   ├── COM = <LazyDPCSignal2D, title: , dimensions: (2|512, 512)>
# │   │   ├── COM_mask
# │   │   │   ├── r = 12.5
# │   │   │   ├── x = 125
# │   │   │   └── y = 125
# │   │   ├── Shifts = <LazyBeamShift, title: , dimensions: (512, 512|2)>
# │   │   └── shift_estimate_mask = <LazySignal, title: , dimensions: (512, 512|)>
# │   ├── Masks
# │   │   ├── Diffraction
# │   │   │   ├── cutoff = <LazySignal2D, title: <0.7001057239470767 $A^{-1}$ mask, dimensions: (|128, 128)>
# │   │   │   ├── direct_beam = <LazySignal2D, title: >0.004612922335229383 $A^{-1}$ mask, dimensions: (|128, 128)>
# │   │   │   └── reflections = <LazySignal2D, title: Reflection mask, dimensions: (|128, 128)>
# │   │   └── Navigation
# │   │       ├── T1 = <LazySignal2D, title: T1, dimensions: (|512, 512)>
# │   │       └── theta_100 = <LazySignal2D, title: theta_100, dimensions: (|512, 512)>
# │   ├── Maximums = <LazyElectronDiffraction2D, title: , dimensions: (|128, 128)>
# │   └── VBF = <LazySignal2D, title: Integrated intensity, dimensions: (|512, 512)>
# └── Signal
#     └── signal_type = electron_diffraction
#
# ├── Acquisition_instrument
# │   └── TEM
# │       ├── Acquisition_parameters
# │       │   ├── alpha = 5
# │       │   ├── beam_energy = 200.0
# │       │   ├── camera = Merlin
# │       │   ├── camera_length = 12.0
# │       │   ├── convergence_angle = None
# │       │   ├── exposure_time = None
# │       │   ├── microscope = 2100F
# │       │   ├── mode = NBD
# │       │   ├── notes = None
# │       │   ├── operator = Emil Christiansen
# │       │   ├── rocking_angle = 1.0
# │       │   ├── rocking_frequency = 100.0
# │       │   ├── scan_rotation = None
# │       │   ├── specimen = 2xxx 250C 24h
# │       │   └── spotsize = 1.0
# │       ├── Detector
# │       │   └── Diffraction
# │       │       └── camera_length = 22.586
# │       ├── beam_energy = 200.0
# │       ├── rocking_angle = 1.0
# │       └── rocking_frequency = 100.0
# ├── General
# │   ├── FileIO
# │   │   ├── 0
# │   │   │   ├── hyperspy_version = 1.7.0.dev0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-07-04T15:35:46.330928+02:00
# │   │   ├── 1
# │   │   │   ├── hyperspy_version = 1.7.0.dev0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-07-06T10:49:07.308573+02:00
# │   │   ├── 10
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-17T11:59:11.705391+01:00
# │   │   ├── 11
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-17T11:59:58.390211+01:00
# │   │   ├── 2
# │   │   │   ├── hyperspy_version = 1.7.0.dev0
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-07-06T10:55:11.324672+02:00
# │   │   ├── 3
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-03T22:30:27.845177+01:00
# │   │   ├── 4
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-03T22:30:31.253745+01:00
# │   │   ├── 5
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-04T13:27:25.807617+01:00
# │   │   ├── 6
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-04T13:27:31.197359+01:00
# │   │   ├── 7
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = load
# │   │   │   └── timestamp = 2022-11-17T10:48:58.454979+01:00
# │   │   ├── 8
# │   │   │   ├── hyperspy_version = 1.7.2
# │   │   │   ├── io_plugin = hyperspy.io_plugins.hspy
# │   │   │   ├── operation = save
# │   │   │   └── timestamp = 2022-11-17T10:49:05.589204+01:00
# │   │   └── 9
# │   │       ├── hyperspy_version = 1.7.2
# │   │       ├── io_plugin = hyperspy.io_plugins.hspy
# │   │       ├── operation = load
# │   │       └── timestamp = 2022-11-17T11:59:06.688449+01:00
# │   └── title =
# ├── HDR
# │   ├── Acquisition Type (Normal, Th_scan, Config) = Normal
# │   ├── Active Counters = Counter 0
# │   ├── Assembly Size (NX1, 2X2) = 1x1
# │   ├── Chip ID = W559_G11, - , - , -
# │   ├── Chip Mode  (SPM, CSM, CM, CSCM) = SPM
# │   ├── Chip Type (Medipix 3.0, Medipix 3.1, Medipix 3RX) = Medipix 3RX
# │   ├── Counter Depth (number) = 12
# │   ├── DAC File = c:\MERLIN_Quad_Config\W559_G11\W559_G11_SPM.dacs,,,
# │   ├── DACs = 068,511,000,000,000,000,000,000,100,255,100,125,100,100,080,100,090,030,128,004,255,126,128,174,172,511,511; ; ;
# │   ├── Dead Time File = Dummy (C:\<NUL>\)
# │   ├── Flat Field File = None
# │   ├── Frames in Acquisition (Number) = 262144
# │   ├── Frames per Trigger (Number) = 1
# │   ├── Gain = SLGM
# │   ├── Gap Fill Mode = None
# │   ├── Humidity (%) = Board Humidity 0.000000
# │   ├── Medipix Clock (MHz) = 160MHz
# │   ├── Readout System = Merlin Quad
# │   ├── Sensor Bias (V) = 120 V
# │   ├── Sensor Polarity (Positive, Negative) = Positive
# │   ├── Software Version = 1.0.0.122
# │   ├── Temperature (C) = Board Temp 0.000000 Deg C
# │   ├── Thresholds (keV) = 4.000000E+1,5.110000E+2,0.000000E+0,0.000000E+0,0.000000E+0,0.000000E+0,0.000000E+0,0.000000E+0
# │   ├── Time and Date Stamp (day, mnth, yr, hr, min, s) = 20/06/2022 12:53:12
# │   ├── Trigger Start (Positive, Negative, Internal) = Rising Edge
# │   ├── Trigger Stop (Positive, Negative, Internal) = Internal
# │   └── bpc File = c:\MERLIN_Quad_Config\W559_G11\W559_G11_SPM.bpc,,,
# ├── Preprocessing
# │   ├── Centering
# │   │   ├── COM = <LazyDPCSignal2D, title: , dimensions: (2|512, 512)>
# │   │   ├── COM_mask
# │   │   │   ├── r = 12.5
# │   │   │   ├── x = 125
# │   │   │   └── y = 125
# │   │   ├── Shifts = <LazyBeamShift, title: , dimensions: (512, 512|2)>
# │   │   └── shift_estimate_mask = <LazySignal, title: , dimensions: (512, 512|)>
# │   ├── Masks
# │   │   ├── Diffraction
# │   │   │   ├── cutoff = <LazySignal2D, title: <0.7001057239470767 $A^{-1}$ mask, dimensions: (|128, 128)>
# │   │   │   ├── direct_beam = <LazySignal2D, title: >0.004612922335229383 $A^{-1}$ mask, dimensions: (|128, 128)>
# │   │   │   └── reflections = <LazySignal2D, title: Reflection mask, dimensions: (|128, 128)>
# │   │   └── Navigation
# │   │       ├── T1 = <Signal2D, title: T1, dimensions: (|512, 512)>
# │   │       └── theta_100 = <LazySignal2D, title: theta_100, dimensions: (|512, 512)>
# │   ├── Maximums = <LazyElectronDiffraction2D, title: , dimensions: (|128, 128)>
# │   └── VBF = <LazySignal2D, title: Integrated intensity, dimensions: (|512, 512)>
# └── Signal
#     └── signal_type = electron_diffraction
# Overwrite '\\idun-samba1.hpc.ntnu.no\emilc\Input\SPED\PhaseMappingPaperSupplementary\data\2022_06_20_prep\20220620_125312\Normalized\SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed.hspy' (y/n)?
# y

# %% [markdown]
# ### 3rd iteration

# %%
decomposition_3 = Decomposition(r'Y:\Input\SPED\PhaseMappingPaperSupplementary\data\2022_06_20_prep\20220620_125312\nndsvd\navmasked2\13048268\SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_6_navmask-T1_navmask-theta_100.hspy')
decomposition_3.plot()
print(decomposition_3.factors.metadata.Decomposition.Decomposition_logfile)
# Out:
# we are running from this directory: /cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2
# The name of the job is: nndsvd3
# The job ID is 13048268
# The job was run on these nodes: idun-02-14
# Number of nodes: 1
# We are using 20 cores
# We are using 20 cores per node
# Total of  cores
# WARNING:silx.opencl.common:Unable to import pyOpenCl. Please install it from: https://pypi.org/project/pyopencl
# 04-11-2022 13:30:34 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition script with arguments:
# 	'hs_file' = /cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/Normalized/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed.hspy
# 	'scale' = None
# 	'logscale' = False
# 	'log_offset' = None
# 	'mask' = True
# 	'navmask' = ['theta_100', 'T1']
# 	'apply_mask' = False
# 	'cutoff' = None
# 	'algorithm' = NMF
# 	'components' = [2, 3, 4, 5, 6, 7, 8, 9, 10]
# 	'poissonian' = True
# 	'max_iter' = 10000
# 	'initialization' = nndsvd
# 	'random_state' = None
# 	'copy' = False
# 	'output_path' = 13048268
# 	'store_signal' = False
# 	'lazy' = False
# 	'precision' = float32
# 	'verbosity' = 2
# 04-11-2022 13:30:34 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Specified output path "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2/13048268" does not exists. I will attempt to create it
# 04-11-2022 13:30:34 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Creating output directory "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2/13048268"
# 04-11-2022 13:30:34 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Created output directory successfully.
# 04-11-2022 13:30:34 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will put outputs at "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2/13048268"
# 04-11-2022 13:30:34 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Loading data signal "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/Normalized/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed.hspy
# 04-11-2022 13:33:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Getting diffraction mask signals
# 04-11-2022 13:33:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Found 3 diffraction masks in the metadata
# 04-11-2022 13:33:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Adding mask <Signal2D, title: <0.7001057239470767 $A^{-1}$ mask, dimensions: (|128, 128)> to diffraction mask
# 04-11-2022 13:33:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Adding mask <Signal2D, title: >0.004612922335229383 $A^{-1}$ mask, dimensions: (|128, 128)> to diffraction mask
# 04-11-2022 13:33:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Adding mask <Signal2D, title: Reflection mask, dimensions: (|128, 128)> to diffraction mask
# 04-11-2022 13:33:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Getting navigation mask signals
# 04-11-2022 13:33:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Found 2 navigation masks in the metadata
# 04-11-2022 13:33:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Filtering masks based on selection: ['theta_100', 'T1'].
# 04-11-2022 13:33:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Adding mask <Signal2D, title: T1, dimensions: (|512, 512)> to navigation mask
# 04-11-2022 13:33:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Adding mask <Signal2D, title: theta_100, dimensions: (|512, 512)> to navigation mask
# 04-11-2022 13:33:07 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Transposing navigation mask
# 04-11-2022 13:33:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 0 of 9
# 04-11-2022 13:33:07 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 04-11-2022 13:33:07 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 04-11-2022 13:33:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 2 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# 04-11-2022 13:44:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 656.7854554653168 seconds
# 04-11-2022 13:44:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=2)
# 04-11-2022 13:44:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 9.29629150611154
# 04-11-2022 13:44:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 2119
# 04-11-2022 13:44:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2/13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_2_navmask-T1_navmask-theta_100.hspy"
# 04-11-2022 13:44:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_2_navmask-T1_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 04-11-2022 13:44:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 04-11-2022 13:44:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 04-11-2022 13:44:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 0 of 9
#
# 04-11-2022 13:44:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 1 of 9
# 04-11-2022 13:44:04 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 04-11-2022 13:44:04 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 04-11-2022 13:44:04 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 3 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# 04-11-2022 14:02:53 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 1129.1017363071442 seconds
# 04-11-2022 14:02:53 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=3)
# 04-11-2022 14:02:53 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 9.216558267003062
# 04-11-2022 14:02:53 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 4142
# 04-11-2022 14:02:53 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2/13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_3_navmask-T1_navmask-theta_100.hspy"
# 04-11-2022 14:02:53 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_3_navmask-T1_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 04-11-2022 14:02:53 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 04-11-2022 14:02:53 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 04-11-2022 14:02:53 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 1 of 9
#
# 04-11-2022 14:02:53 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 2 of 9
# 04-11-2022 14:02:53 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 04-11-2022 14:02:53 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 04-11-2022 14:02:53 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 4 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# 04-11-2022 14:42:03 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 2349.9855194091797 seconds
# 04-11-2022 14:42:03 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=4)
# 04-11-2022 14:42:03 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 9.146111300914228
# 04-11-2022 14:42:03 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 6850
# 04-11-2022 14:42:03 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2/13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_4_navmask-T1_navmask-theta_100.hspy"
# 04-11-2022 14:42:03 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_4_navmask-T1_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 04-11-2022 14:42:03 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 04-11-2022 14:42:03 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 04-11-2022 14:42:03 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 2 of 9
#
# 04-11-2022 14:42:03 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 3 of 9
# 04-11-2022 14:42:03 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 04-11-2022 14:42:03 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 04-11-2022 14:42:03 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 5 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# 04-11-2022 15:24:47 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 2563.327969789505 seconds
# 04-11-2022 15:24:47 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=5)
# 04-11-2022 15:24:47 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 9.100338990321708
# 04-11-2022 15:24:47 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 6828
# 04-11-2022 15:24:47 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2/13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_5_navmask-T1_navmask-theta_100.hspy"
# 04-11-2022 15:24:47 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_5_navmask-T1_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 04-11-2022 15:24:47 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 04-11-2022 15:24:47 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 04-11-2022 15:24:47 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 3 of 9
#
# 04-11-2022 15:24:47 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 4 of 9
# 04-11-2022 15:24:47 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 04-11-2022 15:24:47 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 04-11-2022 15:24:47 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 6 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# 04-11-2022 16:11:06 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 2779.3906939029694 seconds
# 04-11-2022 16:11:06 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=6)
# 04-11-2022 16:11:06 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 9.06082074622464
# 04-11-2022 16:11:06 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 7403
# 04-11-2022 16:11:06 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2/13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_6_navmask-T1_navmask-theta_100.hspy"
# 04-11-2022 16:11:06 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_6_navmask-T1_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 04-11-2022 16:11:06 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 04-11-2022 16:11:06 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 04-11-2022 16:11:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 4 of 9
#
# 04-11-2022 16:11:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 5 of 9
# 04-11-2022 16:11:07 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 04-11-2022 16:11:07 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 04-11-2022 16:11:07 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 7 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# 04-11-2022 16:58:19 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 2832.5309674739838 seconds
# 04-11-2022 16:58:19 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=7)
# 04-11-2022 16:58:19 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 9.023785420105327
# 04-11-2022 16:58:19 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 7975
# 04-11-2022 16:58:19 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2/13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_7_navmask-T1_navmask-theta_100.hspy"
# 04-11-2022 16:58:19 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_7_navmask-T1_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 04-11-2022 16:58:19 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 04-11-2022 16:58:19 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 04-11-2022 16:58:20 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 5 of 9
#
# 04-11-2022 16:58:20 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 6 of 9
# 04-11-2022 16:58:20 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 04-11-2022 16:58:20 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 04-11-2022 16:58:20 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 8 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# /cluster/projects/itea_lille-nv-fys-tem/miniconda3/envs/pyxem0.14.1/lib/python3.10/site-packages/sklearn/decomposition/_nmf.py:1637: ConvergenceWarning: Maximum number of iterations 10000 reached. Increase it to improve convergence.
#   warnings.warn(
# 04-11-2022 17:57:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 3541.003115415573 seconds
# 04-11-2022 17:57:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=8)
# 04-11-2022 17:57:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 8.994906785703568
# 04-11-2022 17:57:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 10000
# 04-11-2022 17:57:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2/13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_8_navmask-T1_navmask-theta_100.hspy"
# 04-11-2022 17:57:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_8_navmask-T1_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 04-11-2022 17:57:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 04-11-2022 17:57:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 04-11-2022 17:57:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 6 of 9
#
# 04-11-2022 17:57:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 7 of 9
# 04-11-2022 17:57:21 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 04-11-2022 17:57:21 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 04-11-2022 17:57:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 9 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# /cluster/projects/itea_lille-nv-fys-tem/miniconda3/envs/pyxem0.14.1/lib/python3.10/site-packages/sklearn/decomposition/_nmf.py:1637: ConvergenceWarning: Maximum number of iterations 10000 reached. Increase it to improve convergence.
#   warnings.warn(
# 04-11-2022 19:00:28 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 3787.3441519737244 seconds
# 04-11-2022 19:00:28 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=9)
# 04-11-2022 19:00:28 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 8.977808826799912
# 04-11-2022 19:00:28 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 10000
# 04-11-2022 19:00:28 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2/13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_9_navmask-T1_navmask-theta_100.hspy"
# 04-11-2022 19:00:28 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_9_navmask-T1_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 04-11-2022 19:00:28 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 04-11-2022 19:00:28 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 04-11-2022 19:00:29 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 7 of 9
#
# 04-11-2022 19:00:29 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Running decomposition 8 of 9
# 04-11-2022 19:00:29 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got navigation mask [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True False ... False False False]
#  [ True False False ... False False False]
#  [ True False False ... False False False]]
# 04-11-2022 19:00:29 - DEBUG - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Got diffraction mask with 13400 nonzero values
# 04-11-2022 19:00:29 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Starting NMF decomposition into 10 components with keyword arguments {'random_state': None, 'copy': False, 'max_iter': 10000, 'init': 'nndsvd'}
# /cluster/projects/itea_lille-nv-fys-tem/miniconda3/envs/pyxem0.14.1/lib/python3.10/site-packages/sklearn/decomposition/_nmf.py:1637: ConvergenceWarning: Maximum number of iterations 10000 reached. Increase it to improve convergence.
#   warnings.warn(
# 04-11-2022 20:26:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition. Elapsed time: 5152.056644439697 seconds
# 04-11-2022 20:26:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decoposition parameters: NMF(init='nndsvd', max_iter=10000, n_components=10)
# 04-11-2022 20:26:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition reconstruction error: 8.965447113410429
# 04-11-2022 20:26:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Decomposition number of iterations: 10000
# 04-11-2022 20:26:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - I will output data to "/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2/13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_10_navmask-T1_navmask-theta_100.hspy"
# 04-11-2022 20:26:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving learning results to "13048268/SPED_512x512x6_5x5_2p315x2p315_NBD_alpha5_spot1p0nm_CL12cm_1deg_100Hz_preprocessed_NMF_10_navmask-T1_navmask-theta_100.hspy" (with _loadings and _factors name identifiers)
# 04-11-2022 20:26:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving factors
# 04-11-2022 20:26:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Saving loadings
# 04-11-2022 20:26:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finshed decomposition 8 of 9
#
# 04-11-2022 20:26:21 - INFO - /cluster/home/emilc/Input/SPED/PhaseMappingPaper/New/PhaseMappingPaper/decomposition.py - Finished decomposition script
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=2
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=2)
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=3
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=3)
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=4
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=4)
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=5
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=5)
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=6
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=6)
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=7
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=7)
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=8
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=8)
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=9
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=9)
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=NMF
#   output_dimension=10
#   centre=None
# scikit-learn estimator:
# NMF(init='nndsvd', max_iter=10000, n_components=10)
# JobId=13048268 JobName=nndsvd3
#    UserId=emilc(1088898) GroupId=kfys_a(14843) MCS_label=N/A
#    Priority=1054448 Nice=0 Account=share-nv-fys-tem QOS=high
#    JobState=RUNNING Reason=None Dependency=(null)
#    Requeue=1 Restarts=0 BatchFlag=1 Reboot=0 ExitCode=0:0
#    DerivedExitCode=0:0
#    RunTime=06:56:01 TimeLimit=10:00:00 TimeMin=N/A
#    SubmitTime=2022-11-04T13:30:21 EligibleTime=2022-11-04T13:30:21
#    AccrueTime=2022-11-04T13:30:21
#    StartTime=2022-11-04T13:30:22 EndTime=2022-11-04T23:30:22 Deadline=N/A
#    SuspendTime=None SecsPreSuspend=0 LastSchedEval=2022-11-04T13:30:22 Scheduler=Main
#    Partition=CPUQ AllocNode:Sid=idun-login1:427115
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=idun-02-14
#    BatchHost=idun-02-14
#    NumNodes=1 NumCPUs=20 NumTasks=1 CPUs/Task=20 ReqB:S:C:T=0:0:*:*
#    TRES=cpu=20,mem=62.50G,node=1,billing=20
#    Socks/Node=* NtasksPerN:B:S:C=0:0:*:* CoreSpec=*
#    JOB_GRES=(null)
#      Nodes=idun-02-14 CPU_IDs=0-19 Mem=64000 GRES=
#    MinCPUsNode=20 MinMemoryNode=62.50G MinTmpDiskNode=0
#    Features=(null) DelayBoot=00:00:00
#    OverSubscribe=OK Contiguous=0 Licenses=(null) Network=(null)
#    Command=/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2/decompose.slurm
#    WorkDir=/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2
#    StdErr=/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2/NMF_nndsvd-13048268.out
#    StdIn=/dev/null
#    StdOut=/cluster/home/emilc/Input/SPED/PhaseMappingPaperSupplementary/data/2022_06_20_prep/20220620_125312/nndsvd/navmasked2/NMF_nndsvd-13048268.out
#    Power=
#    MailUser=emil.christiansen@ntnu.no MailType=INVALID_DEPEND,BEGIN,END,FAIL,REQUEUE,STAGE_OUT

# %%
decomposition_3.export_as_png(cmap=gray_cmap)

# %%
decomposition_3.plot()

# %%
theta_001 = DecomposedPhase('theta_001', decomposition_3, [4], value=1)

# %%
theta_001.estimate_thresholds()
# Out:
# skimage.filters.thresholding.threshold_isodata
# skimage.filters.thresholding.threshold_li
# skimage.filters.thresholding.threshold_mean
# skimage.filters.thresholding.threshold_minimum
# skimage.filters.thresholding.threshold_otsu
# skimage.filters.thresholding.threshold_triangle
# skimage.filters.thresholding.threshold_yen
# {4: None}

# %%
theta_001.estimate_thresholds(method=threshold_isodata, update=True)
# Out:
# {4: 0.020550247842038516}

# %%
theta_001.plot()

# %% [markdown]
# # Make results

# %%
output_path = Path(r'C:\Users\emilc\OneDrive - NTNU\NORTEM\Data\NMF\supplementary/')

# %% [markdown]
# ## Make Phase map

# %%
phasemap = PhaseMap([thetap_100, T1, theta_001])
phasemap.plot_phase_map(cmap=cmap, vmin=0, vmax=4)
rgba_fig = phasemap.make_RGBA(normalize_colors=True, normalize_alpha=True)
phasemap.save(output_path / 'NMF_phasemap.hspy')
rgba_fig.savefig(output_path / 'rgba.png')

# %% [markdown]
# ## Make plots

# %%
phasemap = hs.load(output_path / 'NMF_phasemap.hspy')

# %%
phasemap.plot()

# %%
for phase_name, phase in phasemap.metadata.Phases:
    factors = phase.metadata.Phase.decomposition.factors
    loadings = phase.metadata.Phase.decomposition.loadings
    datapath = Path(phase.metadata.Phase.decomposition.path)

    axis_size = 6 #inches
    dpi=150
    gray_cmap = plt.colormaps.get('Greys')
    gray_cmap.set_bad('lightblue')

    fig = plt.figure(figsize=(3, 3), frameon=False, dpi=dpi)
    ax = fig.add_axes((0, 0, 1, 1), xticks=[], yticks=[], frameon=False)
    ax.imshow(phase.data, cmap="gray_r")
    fig.savefig(output_path / f"{phase.metadata.Phase.name}_phaseimage.png", dpi=dpi)

    for component, (factor, loading) in enumerate(zip(factors, loadings)):
        print(f"{phase_name}: {component}")
        
        fig, axes = plt.subplots(nrows=1, ncols=2, subplot_kw={'xticks': [], 'yticks': []}, figsize=(axis_size*2, axis_size), dpi=dpi)
        axes[0].imshow(loadings.inav[component].data,cmap=gray_cmap)
        axes[1].imshow(factors.inav[component].data, norm=SymLogNorm(0.03),cmap=gray_cmap)
        axes[0].annotate(f'Loading {component}', (0.02, 0.98), xycoords='axes fraction', color='w', ha='left', va='top', bbox=dict(facecolor='k', alpha=0.5))
        axes[1].annotate(f'Factor {component}', (0.02, 0.98), xycoords='axes fraction', color='w', ha='left', va='top', bbox=dict(facecolor='k', alpha=0.5))
        plt.tight_layout()
        fig.savefig(output_path / f'{phase.metadata.Phase.name}_{component}.png', dpi=dpi)
        plt.close('all')

        fig = plt.figure(figsize=(3, 3), frameon=False, dpi=dpi)
        ax = fig.add_axes((0, 0, 1, 1), xticks=[], yticks=[], frameon=False)
        ax.imshow(loadings.inav[component].data, cmap=gray_cmap)
        fig.savefig(output_path / f'{phase.metadata.Phase.name}_loading_{component:03d}.png', dpi=dpi)


        factor_image = factors.inav[component].deepcopy()
        factor_image = factor_image.data
        #if False:
        #    factor_image[mask] = np.nan
        fig = plt.figure(figsize=(3, 3), frameon=False, dpi=dpi)
        ax = fig.add_axes((0, 0, 1, 1), xticks=[], yticks=[], frameon=False)
        ax.imshow(factor_image, cmap=gray_cmap)
        fig.savefig(output_path / f'{phase.metadata.Phase.name}_factor_{component:03d}.png', dpi=dpi)
# Out:
# theta_001: 0
# theta_001: 1
# theta_001: 2
# theta_001: 3
# theta_001: 4
# theta_001: 5
# theta_100: 0
# theta_100: 1
# theta_100: 2
# theta_100: 3
# theta_100: 4

# %% [markdown]
# ## Compare

# %%
gt = hs.load(r'C:\Users\emilc\OneDrive - NTNU\NORTEM\Data\2021_10_06_2xxx_24h_250C\Ground_truth_all.hdf5')
gt.plot(cmap=cmap)

pm = hs.load(r'NMF_phasemap.hspy')
pm.plot(cmap=cmap)

difference = gt - pm
difference = np.abs(difference.data) > 0

percentage_error = np.count_nonzero(difference) / np.multiply(*gt.axes_manager.signal_shape)
print(f'Percentage error of NMF phase map: {percentage_error:.0%}\nSuccessrate: {1-percentage_error:.0%}')

percentage_error = np.count_nonzero(difference[gt.data>0]) / np.count_nonzero(gt.data)
print(f'Percentage error of NMF phase map (disregarding ground_truth Al pixels): {percentage_error:.0%} (Successrate: {1-percentage_error:.0%})')

fig = plt.figure(figsize=(ax_size*2, ax_size*2), frameon=False)
ax = fig.add_axes([0, 0, 1, 1], xticks=[], yticks=[], frameon=False)
ax.imshow(difference, cmap='Greys_r')
fig.savefig('GT_error.png')
error_map_signal = hs.signals.Signal2D(difference)
error_map_signal.save('GT_error.hspy')
# Out:
# C:\Users\emilc\Miniconda3\envs\pyxem0.14.1\lib\site-packages\hyperspy\misc\utils.py:471: VisibleDeprecationWarning: Use of the `binned` attribute in metadata is going to be deprecated in v2.0. Set the `axis.is_binned` attribute instead.
#   warnings.warn(
# C:\Users\emilc\Miniconda3\envs\pyxem0.14.1\lib\site-packages\hyperspy\io.py:560: VisibleDeprecationWarning: Loading old file version. The binned attribute has been moved from metadata.Signal to axis.is_binned. Setting this attribute for all signal axes instead.
#   warnings.warn('Loading old file version. The binned attribute '
